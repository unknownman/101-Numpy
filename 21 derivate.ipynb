# %% [markdown]
# <font size="6">
# $$
# f'(x) = \lim_{h \to 0} \frac{f(x + h) - f(x)}{h}
# $$
# </font>
#
# ![image.png](attachment:1af555e8-b225-4f64-84f9-71c6a5b9be8c.png)
#
# ![image.png](https://upload.wikimedia.org/wikipedia/commons/7/7a/Graph_of_sliding_derivative_line.gif)
#
# ---
#
# ![image.png](attachment:cae301ad-d753-4019-baec-231ee26fe405.png)
#
# ### روش تفاضل پیشرو:
#
# $$
# f'(x) \approx \frac{f(x + h) - f(x)}{h}
# $$
#
# ### روش تفاضل پسرو:
#
# $$
# f'(x) \approx \frac{f(x) - f(x - h)}{h}
# $$
#
# ### روش تفاضل مرکزی:
#
# $$
# f'(x) \approx \frac{f(x + h) - f(x - h)}{2h}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**3

x = np.linspace(-5,5, 100)

h = x[1] - x[0]

derivative = (f(x + h) - f(x - h)) / (2 * h)

plt.plot(x, f(x), label='f(x)')
plt.plot(x, derivative, label="f'(x)")
plt.legend()
plt.title("numerical derivative")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
